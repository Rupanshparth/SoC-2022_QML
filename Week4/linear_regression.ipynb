# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
d = pd.read_csv('weatherHistory.csv')
d_new = d[['Temperature (C)', 'Humidity']]
d_new.columns = ['Temp', 'Humidity']
d_new.head()
# Out:
#        Temp  Humidity
# 0  9.472222      0.89
# 1  9.355556      0.86
# 2  9.377778      0.89
# 3  8.288889      0.83
# 4  8.755556      0.83

# %%
sns.lmplot(x ="Temp", y ="Humidity", data = d_new, order = 2, ci = None)

# %%
d_new.fillna(method = 'ffill', inplace = True)
# Out:
# C:\Users\PC-LENOVO\AppData\Local\Temp\ipykernel_3316\2984508001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d_new.fillna(method = 'ffill', inplace = True)

# %%
X = np.array(d_new['Temp']).reshape(-1,1)
y = np.array(d_new['Humidity']).reshape(-1,1)
#d_new.dropna(inplace = True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
reg = LinearRegression()
reg.fit(X_train,y_train)
print(reg.score(X_test,y_test))
# Out:
# 0.39488293872864

# %%
y_pred = reg.predict(X_test)
plt.scatter(X_test, y_test, color ='b')
plt.plot(X_test, y_pred, color ='k')
 
plt.show()

# %% [markdown]
# Now we will implement multi-variable linear regression of humidity against pressure and pressure on the weather dataset.

# %%
md = pd.read_csv('weatherHistory.csv')
X = md[['Temperature (C)', 'Pressure']]
y = md['Humidity']
X.coulumn
