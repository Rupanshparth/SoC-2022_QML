# %% [markdown]
# Results with number of optimization epochs = 30 and quantum layers = 1
#
# ![Screenshot%20%28540%29.png](attachment:Screenshot%20%28540%29.png)

# %% [markdown]
# Results with number of optimization epochs = 20 and quantum layers = 1
# ![Screenshot%20%28541%29.png](attachment:Screenshot%20%28541%29.png)

# %% [markdown]
# Results with number of optimization epochs = 10 and quantum layers = 1
#
# ![Screenshot%20%28542%29.png](attachment:Screenshot%20%28542%29.png)

# %% [markdown]
# Results with number of epochs = 10 and number of quantum layers = 2
# ![Screenshot%20%28543%29.png](attachment:Screenshot%20%28543%29.png)
